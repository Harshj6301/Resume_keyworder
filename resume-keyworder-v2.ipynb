# %% [markdown]
# <hr>
#
# ## Introduction
# To analyze and give out an insight to what job description is and how your skills / resume align to it.
#
# <hr>

# %%
from wordcloud import WordCloud # For plotting wordcloud
import matplotlib.pyplot as plt # For figure or plotting if required
plt.style.use('ggplot')
import random
import pandas as pd
from nltk.corpus import stopwords
import seaborn as sns

# %% [markdown]
# # RUN <code>main()</code> at bottom

# %%
JOB_DESCRIPTION = '''This position is a part of the Consumer and Market Intelligence, Decision Sciences team. This is a global team of 40 members supporting business and enabling strategies through data-driven solutions. Team is based out of Minneapolis Minnesota and Mumbai India location.

We are looking for a Data Scientist who can work independently on the strategic analytical projects involving data integration from multiple sources, deploying statistical/predictive models, visualization reporting and as per requirement build ML enabled web applications using R-shiny and/or flask. This candidate will work with stakeholders, collaborate with other teams to understand business problem, and define the analytical approaches to fulfill business needs.

We expect the candidate to work directly with business stakeholders to:

Comprehend the business needs, develop a solution framework, execute the plan, and articulate insight stories back to the client so they can consume and take strategic actions
Have hands-on experience in data management by handling variety of point-of-sales, online, big data (structured & unstructured) and advanced analytics techniques and developing intuitive visualization reporting.
Ability to translate complicated analytical techniques to non-technical audiences.
Managing multiple projects and meeting stakeholder expectations

Job Responsibilities

95% of Time Operational Responsibilities

Probe to understand the underlying business needs from stakeholders, plan & execute analytical solutions and share actionable insights that drives strategy & impact
Deploy statistical/predictive analyses utilizing data from multiple sources and develop visualization reports to share key conclusions based on the analysis outcome
Gain expertise in using the tools developed in-house and by external vendors
Be able to explore and deal with variety of large data sets and proactively make recommendations for an analysis plan and follow-through with the proposed plan.
Ability to find unique ways to “connect” disparate data sources to enable analytics
Provide the “story” not just the data
Collaborate with larger team for gathering data
Manage stakeholder relationship
End-to-end management of multiple projects

5% of Time Self-Development

Complete and Leverage IDP for self-development
Identify and undergo self-learning modules
Participate in project related trainings
Make presentations on the right forum

Desired Profile

Education

Minimum Degree Requirements: Bachelors

Preferred Degree Requirements: Masters

Preferred Major Area of Study: Statistics, Mathematics, Economics/Econometrics, Computer Science

Experience

Minimum years of related experience required: 3-4 years – analytics experience; Big data management, statistical/ML predictive models, visualization is desired.

Preferred years of related experience: 5+ years – analytics experience; Big data management, statistical/ML predictive models, visualization is desired.

Specific Job Experience Or Skills Needed

Technical acumen in data wrangling utilizing multiple internal and external data sources
Excellent data interpretations and data crunching skills
Experience in deploying analytical techniques mainly, predictive modeling inferential statistics, machine learning
Good handle in SQL, Advanced Excel, and Scripting languages R and/or Python
Experience in ML model deployment and building easy, usable web applications using R-shiny and/or flask and ploty-dash/streamlite for visualization
Strong organizational skills and attention to detail
Experience working by collaborating with cross functional teams to build effective plans for conducting analysis
Problem solving aptitude and storytelling presentation skills
Ability to manage stakeholders and multiple projects together with effective communication skills
Exposure to Google cloud platforms, Hadoop, Cloud Storage and API’s is an advantage
Prior experience working in CPG, Retail, Ecommerce industry is preferred

Competencies/Behaviors required for job

Leading Change

Continually asks him/herself, “Why do I (or we) do it this way?”
Continuous Improvement mindset
Remains curious despite having developed expertise

Delivers Outstanding Results

Thinks through ways of implementing his knowledge/experience which the process could benefit
Makes quality decisions in a timely manner
Proactively anticipates and addresses issues/opportunities
Consistently accomplishes assigned tasks
Delivers high quality work within established timeframes
Pays attention to detail and focuses on accuracy
Seeks assistance, information, and resources to make good decisions
Displays sense of urgency even in absence of assigned deadlines

Technical Expertise

Adapts to tools & technology as per the process needs
Acquires foundational knowledge and skills in his/her functional area
Seeks to understand the principles of service excellence & how to apply them in own area
Strives to continuously expand the technical knowledge base

Influence and Impact

Maintain good working relationship with peer group delivering as a Team
Set examples in the peer group

Agility

Shares and collaborates with peers on application of relevant industry trends'''

RESUME = '''Seeking a position as a Entry level/Junior Data Scientist to utilize my skills and knowledge for the
organization’s aim.
Summary
An IT graduate with a keen interest in data science and deep learning using python and its libraries.
Passionate about developing innovative solutions that leverage the power of machine learning to solve
complex problems and about exploring new techniques and tools to improve the performance of machine
learning models. Eager to apply my skills to develop predictive models and drive business value through
data-driven insights. Curious for an opportunity to learn and grow in a dynamic, data-driven environment.
Education
Bachelor of Science in Information Technology, 7.35
Annasaheb Vartak College of Arts, Commerce and Science, Vasai, 2022
Certifications
Cognizant Artificial Intelligence Virtual Experience Program on Forage
Modeled data and built a model to forecast estimated levels for stocks required for a store (May 2023)
British Airways Virtual Experience Program on Forage
Used Web scraping to gain company insights, predicted customer buying behavior with machine
learning. (May 2023)
Data Science Master Program by Simplilearn
Apr 2022 to Nov 2022
IBM Data Science Professional Certificate (In progress)
Tools and Technologies
Pandas
Sci-kit learn
Matplotlib
Seaborn
Plotly
Tensorflow with keras
Numpy
Fastai
Data analytics
Machine learning
Neural networks
Projects
Car damage classifier, Built a model using transfer learning and fine tuned it to classify whether cars
are damaged or not with ~90% accuracy and deployed the model on HuggingFace spaces.
Ecommerce Spends Analysis, Requested personal amazon orders data and analyzed it using pandas,
plotly libraries to derive insights about the top 10 elements and it’s related cost structure, orders.
Diabetes Prediction, Performed EDA and some feature engineering to build various models with
different machine learning algorithms and a neural network with different evaluation metrics and
predict whether a patient has diabetes or not with top model performing at ~80% accuracy.
Achievements and awards
Qualified for Coursera's first ever Data Science coding competition, a retention prediction challenge and
scored 72%.'''

SKILLS = 'tf,aws' # Separate by commas ','

# %% [markdown]
# ### Functions implemented

# %%
def desc():
    '''desc: Takes in string of job description and returns a wordcloud and list of words in the job description
    eg: 
       image,list = desc()
        paste job description in the input box'''
    #print('Paste Job description\n')
    try:
        input_data = JOB_DESCRIPTION
        raw_data = input_data
    except:
        print('Provide input..')
    
    print('')
    #print('Paste Resume\n')
    try:
        input_data1 = RESUME
        raw_data1 = input_data1
    except:
        print('Provide input..')
    try:
        cloud = wc(input_data)
        cloud1 = wc(input_data1)
        return cloud, raw_data, cloud1, raw_data1
    except:
        print('Wordcloud data not provided..')

# %%
# Function to store the user inputted skills
L_skills = []

def skills_in():
    """skills_in: Takes in strings separated by commas, provide skills, dosen't returns anything but list of your inputted strings can be accessed
                  by calling L_skills.
                  Note: Running function again when it's already has values stored in will erase the previous values and store in new ones"""
    L_skills.clear()
    print = ('Insert your skills (separate with comma)')
    skills = SKILLS
    List_skills = skills.split(sep=',')
    for skills in List_skills:
        L_skills.append(skills)
    return L_skills

# %%
# Function for plotting wordcloud of description
def wc(text):
    wordcloud = WordCloud(width=1124,height=514)
    wc = wordcloud.generate_from_text(text)
    return wc.to_image()

# %%
# Process data
def process_data(data_in):
    p0 = data_in.lower() # -> Convert description to lowercase
    p1 = p0.replace('(','').replace(')','').replace('/',' ').replace('!','').replace(':','').replace('.','').replace('|','').replace('•','').replace(',','').replace('	','') # -> replace special chracters with space
    p2 = p1.split() # -> split words
    p3 = [word for word in p2 if word not in stopwords.words('english')] # -> Loop through description and take out stopwords
    p4 = pd.Series(p3) # ->
    return p4

# %%
# Function showing count of words
def count(data,data2):
    df1 = pd.DataFrame(data.value_counts(),columns=['Count']).reset_index()
    df2 = pd.DataFrame(data2.value_counts(),columns=['Count']).reset_index()
    df1 = df1.rename({'index':'Job_description keywords'},axis=1)
    df2 = df2.rename({'index':'Resume keywords'},axis=1)
    
    concated_df = pd.concat([df1, df2], axis=1)
    return concated_df

# %%
# Function which takes in data from job description and resume and shows matched and unmatched words
match = []
not_match = []

#set_1 =set(data)
#set_2 = set(resume_data)

def keyword_matcher(set_1,set_2):
    match.clear()
    not_match.clear()
    for i in set(set_1):
        if i in set(set_2):
            match.append(i)
        else:
            not_match.append(i)

# %%
# Plotting function to plot distribution of keywords
def plot():
    ax = sns.barplot(x=['Matched keywords','Unmatched keywords'],y=[len(match),(len(match) + len(not_match))])
    ax.set_title('Distribution of keywords')
    for i in ax.containers:
        ax.bar_label(i)
        plt.show()

# %%
# MAIN function
def main():
    """main function, calls all functions
    returns two cloud -> wordcloud objects, DataFrame consisting of count of keywords -> DataFrame"""
    try:
        skills_in()
    
        cloud,job_data,cloud2,resume_data = desc()
    
        processed_data = process_data(job_data)
        processed_data2 = process_data(resume_data)
    
        concated_df = count(processed_data,processed_data2)
    
        keyword_matcher(processed_data,processed_data2)
        print('Your skills:',L_skills)
        print('\n')
        print('='*185)
        print('\nMatched keywords:',match,'\n\nUnmatched keywords:',not_match)
        print('\n\nKeyword match score:',round(len(match) / (len(match) + len(not_match))* 100,ndigits=3),'%\n\n')
        plot()
        return cloud,cloud2, concated_df
    except:
        print('Run in edit mode')

# %%
job_description_cloud, resume_cloud, df = main()
# Out:
# Your skills: ['tf', 'aws']
#
#
# ...
#
# Matched keywords: ['techniques', 'using', 'leverage', 'web', 'insights', 'business', 'technology', 'science', 'ecommerce', 'projects', 'solutions', 'machine', 'related', 'curious', 'model', 'gain', 'tools', 'data', 'accuracy', 'position', 'analysis', 'experience', 'analytics', 'education', 'developing', 'build', 'predictive', 'python', 'scientist', 'data-driven', 'required', 'learning', 'apply', 'develop', 'models', 'skills', 'information', 'knowledge', 'intelligence']
#
# ...

# %%
job_description_cloud
# Out:
# <PIL.Image.Image image mode=RGB size=1124x514>

# %%
resume_cloud
# Out:
# <PIL.Image.Image image mode=RGB size=1124x514>

# %%
df
# Out:
#     Job_description keywords  Count Resume keywords  Count
# 0                       data     15            data    8.0
# 1                 experience     10        learning    7.0
# 2                   multiple      6         science    6.0
# 3                     skills      6         machine    5.0
# 4                   business      6           model    4.0
# ..                       ...    ...             ...    ...
# 327                gathering      1             NaN    NaN
# 328               end-to-end      1             NaN    NaN
# 329                       5%      1             NaN    NaN
# 330                 complete      1             NaN    NaN
# 331                   trends      1             NaN    NaN
#
# [332 rows x 4 columns]
